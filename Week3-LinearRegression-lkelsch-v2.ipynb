# %% [markdown]
# # Assigment 3
# This assigment focuses on getting comfortable with working with multidimensional data and linear regression.
# Key items include:
# - Creating random n-dimensional data
# - Creating a Model that can handle the data
# - Plot a subset of the data along with the prediction
# - Using a Dataset to read in and choose certain columns to produce a model
# - Create several models from various combinations of columns
# - Plot a few of the results

# %% [markdown]
# ## 1. Create a 4 dimensional data set with 64 elements and show all 4 scatter 2D plots of the data $x_1$ vs. $y$, $x_2$ vs. $y$,  $x_3$ vs. $y$, $x_4$ vs. $y$

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
n = 64
x = np.linspace(0, 1, n) + np.random.rand(4, n)
x = np.vstack([x, np.ones(len(x.T))]).T
y = np.linspace(0, 1, n) + np.random.rand(n) - 1

# %%
plt.scatter(x.T[0],y)

# %%
plt.scatter(x.T[1],y)

# %%
plt.scatter(x.T[2],y)

# %%
plt.scatter(x.T[3],y)

# %% [markdown]
# ## 2.  Create a Linear Regression model (LIKE WE DID IN CLASS) to fit the data. *Use the example from Lesson 3 and DO NOT USE a library that calculates automatically*. We are expecting 5 coefficients to describe the linear model.
#
# ## After creating the model (finding the coefficients), calculate a new column $y_p=\Sigma\beta_n\cdot x_n$

# %%
left = np.linalg.inv(np.dot(x.T, x))

# %%
right = np.dot(y.T, x)

# %%
beta = np.dot(left, right)
beta
# Out:
# array([ 0.28087092,  0.3284872 ,  0.04104231,  0.15136526, -0.78682082])

# %%
yp = np.sum(beta)*x
yp
# Out:
# array([[0.01430027, 0.01200598, 0.01274969, 0.01490423, 0.01494488],
#        [0.01107542, 0.01160388, 0.00470965, 0.00828774, 0.01494488],
#        [0.01129968, 0.00581781, 0.01325303, 0.00383871, 0.01494488],
#        [0.01323273, 0.0107643 , 0.00249966, 0.01218071, 0.01494488],
#        [0.00139399, 0.01128099, 0.00468241, 0.0076024 , 0.01494488],
#        [0.00885588, 0.00397551, 0.00292915, 0.01526143, 0.01494488],
#        [0.00977163, 0.01343852, 0.00853422, 0.00223923, 0.01494488],
#        [0.0107401 , 0.0074054 , 0.01435176, 0.00772401, 0.01494488],
#        [0.00960129, 0.00882468, 0.00384923, 0.00408657, 0.01494488],
#        [0.01142603, 0.00798904, 0.01688419, 0.01633778, 0.01494488],
#        [0.01201026, 0.00768623, 0.01130083, 0.01474301, 0.01494488],
#        [0.014622  , 0.01069448, 0.01255711, 0.0094501 , 0.01494488],
#        [0.00383423, 0.00662916, 0.00825652, 0.00847037, 0.01494488],
#        [0.0031135 , 0.01089635, 0.01044686, 0.01550749, 0.01494488],
#        [0.00499524, 0.01484431, 0.00384228, 0.00855886, 0.01494488],
#        [0.01063629, 0.01368365, 0.00486829, 0.00530149, 0.01494488],
#        [0.00759913, 0.01458426, 0.00641759, 0.01409504, 0.01494488],
#        [0.00949842, 0.01312875, 0.00442069, 0.016921  , 0.01494488],
#        [0.00749149, 0.01522031, 0.01358266, 0.00496191, 0.01494488],
#        [0.00908229, 0.01357778, 0.00828272, 0.01877213, 0.01494488],
#        [0.01151263, 0.00795449, 0.0183485 , 0.01419054, 0.01494488],
#        [0.01148648, 0.00981295, 0.01336882, 0.0080971 , 0.01494488],
#        [0.00816223, 0.00678916, 0.01871937, 0.01280873, 0.01494488],
#        [0.00832897, 0.01281089, 0.0082777 , 0.01982946, 0.01494488],
#        [0.01136571, 0.0112921 , 0.00993848, 0.01270625, 0.01494488],
#        [0.01278443, 0.01690263, 0.01470103, 0.01908049, 0.01494488],
#        [0.00940815, 0.01499641, 0.01432772, 0.00752158, 0.01494488],
#        [0.01574999, 0.01632909, 0.00858426, 0.01673395, 0.01494488],
#        [0.01948398, 0.01767698, 0.01372374, 0.02036912, 0.01494488],
#        [0.00893765, 0.01036813, 0.01574098, 0.01830612, 0.01494488],
#        [0.00802289, 0.01800552, 0.01844432, 0.01530101, 0.01494488],
#        [0.01934989, 0.02017846, 0.01278307, 0.01841887, 0.01494488],
#        [0.01954608, 0.00759398, 0.02141794, 0.0191527 , 0.01494488],
#        [0.0085901 , 0.01426661, 0.00791482, 0.01487794, 0.01494488],
#        [0.00965943, 0.01218552, 0.01022449, 0.00880246, 0.01494488],
#        [0.01083729, 0.00938523, 0.02106802, 0.01544571, 0.01494488],
#        [0.01905027, 0.02139256, 0.0199856 , 0.02160172, 0.01494488],
#        [0.01499852, 0.0202116 , 0.01766186, 0.01513251, 0.01494488],
#        [0.01835604, 0.00953219, 0.01506963, 0.01438341, 0.01494488],
#        [0.01148596, 0.01917748, 0.02195713, 0.02259515, 0.01494488],
#        [0.01184927, 0.02358944, 0.02074469, 0.00956749, 0.01494488],
#        [0.01245937, 0.01847324, 0.01768043, 0.023956  , 0.01494488],
#        [0.01848233, 0.01375835, 0.0126942 , 0.01861448, 0.01494488],
#        [0.01848673, 0.01370074, 0.02173657, 0.01924831, 0.01494488],
#        [0.01859933, 0.0137563 , 0.01073776, 0.01747079, 0.01494488],
#        [0.01867087, 0.01372966, 0.01776764, 0.01150318, 0.01494488],
#        [0.02275774, 0.0212511 , 0.02427206, 0.01684423, 0.01494488],
#        [0.01428818, 0.02218279, 0.01390203, 0.01769681, 0.01494488],
#        [0.02526451, 0.01884548, 0.01727543, 0.01536673, 0.01494488],
#        [0.02050673, 0.01224556, 0.01523897, 0.01820189, 0.01494488],
#        [0.01455292, 0.02113266, 0.02218805, 0.01334698, 0.01494488],
#        [0.02058238, 0.02257859, 0.01278892, 0.02138897, 0.01494488],
#        [0.01464142, 0.02354191, 0.0229395 , 0.01927298, 0.01494488],
#        [0.02223659, 0.01909531, 0.02136671, 0.02648447, 0.01494488],
#        [0.01331063, 0.0159802 , 0.01402172, 0.01386088, 0.01494488],
#        [0.01640035, 0.0211033 , 0.01979974, 0.01467426, 0.01494488],
#        [0.02576343, 0.01923757, 0.02661108, 0.01407287, 0.01494488],
#        [0.0201526 , 0.02669103, 0.02783095, 0.01363759, 0.01494488],
#        [0.02054677, 0.0212382 , 0.01693011, 0.0234512 , 0.01494488],
#        [0.02617904, 0.02750835, 0.02486752, 0.02689691, 0.01494488],
#        [0.0172029 , 0.02019656, 0.02777977, 0.02102144, 0.01494488],
#        [0.02385146, 0.02702631, 0.01811529, 0.02785661, 0.01494488],
#        [0.01508513, 0.02525384, 0.01880734, 0.01939858, 0.01494488],
#        [0.02882959, 0.02357947, 0.02289916, 0.01584735, 0.01494488]])

# %%
yp_0 = yp[:, :1]
yp_1 = yp[:, 1:2]
yp_2 = yp[:, 2:3]
yp_3 = yp[:, 3:4]

# %% [markdown]
# ## 3. Plot the model's prediction as a different color on top of the scatter plot from Q1 in 2D for all 4 of the dimensions ($x_1 \rightarrow y_p, x_2 \rightarrow y_p, x_3 \rightarrow y_p, x_4 \rightarrow y_p$)

# %%
pred1 = np.dot(x, beta)
pred1
# Out:
# array([-6.82068724e-02, -2.26745250e-01, -3.71306491e-01, -1.71295596e-01,
#        -4.22809379e-01, -3.70388272e-01, -2.61680719e-01, -3.04559428e-01,
#        -3.60449715e-01, -1.84642925e-01, -2.11804138e-01, -1.46756526e-01,
#        -4.60588470e-01, -3.03052402e-01, -2.69426729e-01, -2.19094883e-01,
#        -1.63061393e-01, -1.36220491e-01, -2.23929449e-01, -1.04816898e-01,
#        -2.01501164e-01, -2.36535176e-01, -3.03058547e-01, -1.25135689e-01,
#        -1.69031354e-01,  5.85899459e-02, -1.64858356e-01,  6.11530310e-02,
#         2.11887611e-01, -1.62320742e-01, -3.46557564e-02,  2.42014004e-01,
#         2.41190970e-04, -1.39378230e-01, -2.20214483e-01, -1.62564704e-01,
#         3.15085293e-01,  1.41076993e-01, -4.52610462e-02,  1.39711881e-01,
#         1.08237588e-01,  1.44564905e-01,  8.63326099e-02,  1.16401417e-01,
#         7.15302976e-02,  3.11536619e-02,  3.45240220e-01,  1.86700087e-01,
#         3.05297691e-01,  9.39377687e-02,  1.47292942e-01,  3.48029805e-01,
#         2.63995118e-01,  3.77721503e-01, -6.52672077e-03,  1.88251903e-01,
#         3.35825730e-01,  3.93145003e-01,  3.50158462e-01,  6.50524411e-01,
#         2.69605873e-01,  5.87361930e-01,  2.99886120e-01,  4.96663753e-01])

# %%
plt.scatter(x.T[0], pred1, c='green')
plt.scatter(x.T[0], yp_0, c='blue')

# %%
plt.scatter(x.T[1], pred1, c='green')
plt.scatter(x.T[1], yp_1, c='blue')

# %%
plt.scatter(x.T[2], pred1, c='green')
plt.scatter(x.T[2], yp_2, c='blue')

# %%
plt.scatter(x.T[3], pred1, c='green')
plt.scatter(x.T[3], yp_3, c='blue')

# %% [markdown]
# ## 4. Read in `mlnn/data/Credit.csv` with Pandas and build a Linear Regression model to predict Credit Rating (`Rating`). Use only the numeric columns in your model, but feel free to experiment which which columns you believe are better predicters of Credit Rating (Column `Rating`)

# %%
import pandas as pd
import numpy as np
credit = pd.read_csv('../data/Credit.csv')
credit.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %% [markdown]
# ## Choose multiple columns as inputs beyond `Income` and `Limit` but clearly, don't use `Rating`

# %%
columns2 = ['Income', 'Limit']
X2 = credit[columns2].values

X2 = np.vstack([X2.T, np.ones(len(X2))]).T
X2
# Out:
# array([[1.48910e+01, 3.60600e+03, 1.00000e+00],
#        [1.06025e+02, 6.64500e+03, 1.00000e+00],
#        [1.04593e+02, 7.07500e+03, 1.00000e+00],
#        ...,
#        [5.78720e+01, 4.17100e+03, 1.00000e+00],
#        [3.77280e+01, 2.52500e+03, 1.00000e+00],
#        [1.87010e+01, 5.52400e+03, 1.00000e+00]])

# %%
columns3 = ['Cards', 'Balance']
X3 = credit[columns3].values

X3 = np.vstack([X3.T, np.ones(len(X3))]).T
X3
# Out:
# array([[  2., 333.,   1.],
#        [  3., 903.,   1.],
#        [  4., 580.,   1.],
#        ...,
#        [  5., 138.,   1.],
#        [  1.,   0.,   1.],
#        [  5., 966.,   1.]])

# %%
columns4 = ['Education', 'Age']
X4 = credit[columns4].values

X4 = np.vstack([X4.T, np.ones(len(X4))]).T
X4
# Out:
# array([[11., 34.,  1.],
#        [15., 82.,  1.],
#        [11., 71.,  1.],
#        ...,
#        [12., 67.,  1.],
#        [13., 44.,  1.],
#        [ 7., 64.,  1.]])

# %%
columns5 = ['Cards', 'Balance', 'Limit']
X5 = credit[columns5].values

X5 = np.vstack([X5.T, np.ones(len(X5))]).T
X5
# Out:
# array([[2.000e+00, 3.330e+02, 3.606e+03, 1.000e+00],
#        [3.000e+00, 9.030e+02, 6.645e+03, 1.000e+00],
#        [4.000e+00, 5.800e+02, 7.075e+03, 1.000e+00],
#        ...,
#        [5.000e+00, 1.380e+02, 4.171e+03, 1.000e+00],
#        [1.000e+00, 0.000e+00, 2.525e+03, 1.000e+00],
#        [5.000e+00, 9.660e+02, 5.524e+03, 1.000e+00]])

# %%
y2 = credit['Rating']
y2
# Out:
# 0      283
# 1      483
# 2      514
# 3      681
# 4      357
#       ...
# 395    307
# 396    296
# 397    321
# 398    192
# 399    415
# Name: Rating, Length: 400, dtype: int64

# %%
model2 = np.linalg.lstsq(X2, y2,rcond=None)[0]
model2
# Out:
# array([2.07464217e-02, 6.65723378e-02, 3.87419069e+01])

# %%
model3 = np.linalg.lstsq(X3, y2,rcond=None)[0]
model3
# Out:
# array([ -2.43584834,   0.29126669, 210.68097469])

# %%
model4 = np.linalg.lstsq(X4, y2,rcond=None)[0]
model4
# Out:
# array([ -1.5104736 ,   0.92634084, 323.68879114])

# %%
model5 = np.linalg.lstsq(X5, y2,rcond=None)[0]
model5
# Out:
# array([4.81235623e+00, 1.70598337e-03, 6.65011947e-02, 2.48972621e+01])

# %% [markdown]
# ### 5. Plot your results using scatter plots (just like in class). Show as many of your columns vs. credit rating that you can.

# %% [markdown]
# Rating ~ Income + Limit

# %%
pred_inc_lim = np.dot(X2, model2)

# %%
plt.scatter(X2.T[0], pred_inc_lim, c='red')
plt.scatter(X2.T[0], y2, c='b')

# %%
plt.scatter(X2.T[1], pred_inc_lim, c='red')
plt.scatter(X2.T[1], y2, c='b')

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(10, 70)
ax.scatter(X2.T[0], X2.T[1], pred_inc_lim, zdir='z', c='r')
ax.scatter(X2.T[0], X2.T[1], y2, zdir='z', c='g')

# %% [markdown]
# Rating ~ Cards + Balance

# %%
pred_card_bal = np.dot(X3, model3)

# %%
plt.scatter(X3.T[0], pred_card_bal, c='red')
plt.scatter(X3.T[0], y2, c='b')

# %%
plt.scatter(X3.T[1], pred_card_bal, c='red')
plt.scatter(X3.T[1], y2, c='b')

# %%
fig2 = plt.figure()
ax = fig2.add_subplot(111, projection='3d')
ax.view_init(10, 10)
ax.scatter(X3.T[0], X3.T[1], pred_card_bal, zdir='z', c='r')
ax.scatter(X3.T[0], X3.T[1], y2, zdir='z', c='g')

# %% [markdown]
# Rating ~ Education + Age

# %%
pred_edc_age = np.dot(X4, model4)

# %%
plt.scatter(X4.T[0], pred_edc_age, c='red')
plt.scatter(X4.T[0], y2, c='b')

# %%
plt.scatter(X4.T[1], pred_edc_age, c='red')
plt.scatter(X4.T[1], y2, c='b')

# %%
fig3 = plt.figure()
ax = fig3.add_subplot(111, projection='3d')
ax.view_init(10, 50)
ax.scatter(X4.T[0], X4.T[1], pred_edc_age, zdir='z', c='r')
ax.scatter(X4.T[0], X4.T[1], y2, zdir='z', c='g')

# %% [markdown]
# Rating ~ Cards + Balance + Limit

# %%
pred_card_bal_lim = np.dot(X5, model5)

# %%
plt.scatter(X5.T[0], pred_card_bal_lim, c='red')
plt.scatter(X5.T[0], y2, c='b')

# %%
plt.scatter(X5.T[1], pred_card_bal_lim, c='red')
plt.scatter(X5.T[1], y2, c='b')

# %%
H = X5.T[2] #limit in color as 4th dimension

# %%
fig4 = plt.figure()
ax = fig4.add_subplot(111, projection='3d')
ax.view_init(5, 14)
grp = ax.scatter(X5.T[0], X5.T[1], pred_card_bal_lim, zdir='z', c=H,  cmap=plt.hot())
grp
ax.scatter(X5.T[0], X5.T[1], y2, zdir='z', c='green')
fig.colorbar(grp)
